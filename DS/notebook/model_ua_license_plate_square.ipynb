# %%
# # запускати один раз, потім можна закрити коментами
# !python.exe -m pip install --upgrade pip
# !pip3 install paddlepaddle
# !pip3 install paddleocr

# %%
import cv2
from matplotlib import pyplot as plt
import os
import numpy as np

# %%
# loading the data required for detecting the license plates using cascade classifier.
current_dir = os.getcwd()
plate_cascade_path = os.path.join(current_dir, '../models/haarcascade_ua_license_plate.xml')
plate_cascade = cv2.CascadeClassifier(plate_cascade_path)

# %%
def detect_plate(img, text="number"):
    """
    Функція призначена для виявлення та обробки номерних знаків на зображенні.

    Параметри:
    img (numpy.array): Зображення, на якому потрібно виявити та обробити номерні знаки.
    text (str, optional): Текст, який можна додати на зображення навколо номерного знаку.

    Повертає:
    numpy.array: Зображення з виділеними номерними знаками та, за бажанням, доданим текстом.
    numpy.array or None: Зображення області номерного знаку для подальшої обробки або None, якщо номерний знак не був виявлений.
    """
    plate_img = img.copy()  # перша копія зображення
    reg_of_intr = img.copy()  # друга копія зображення

    # виявляє номерні знаки та повертає координати та розміри виявлених контурів номерних знаків
    plate_rect = plate_cascade.detectMultiScale(
        plate_img, scaleFactor=1.4, minNeighbors=7
    )

    # print(f"{plate_rect = }")
    if (len(plate_rect) > 0):
        plate_rect = plate_rect[[len(plate_rect) - 1]]
    print(f"{plate_rect = }")

    # виділення частини номерного знака для розпізнавання
    for x, y, w, h in plate_rect:
        plate = reg_of_intr[y : y + h, x : x + w, :]
        # print(f"{plate = }")
        # малювання прямокутника по межі номера
        cv2.rectangle(plate_img, (x + 2, y), (x + w - 3, y + h - 5), (51, 181, 155), 3)

    # Додавання тексту
    if text != "":
        plate_img = cv2.putText(
            plate_img,
            text,
            (x - w // 2, y - h // 2),
            cv2.FONT_HERSHEY_COMPLEX_SMALL,
            0.5,
            (51, 181, 155),
            1,
            cv2.LINE_AA,
        )

    # Повертаємо оброблене зображення з виділеними номерними знаками та область номерного знаку
    return plate_img, plate

# %%
# функція виводу зображень
def display(img_, title=''):
    img = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10,6))
    ax = plt.subplot(111)
    ax.imshow(img)
    plt.axis('off')
    plt.title(title)
    plt.show()

# %%
car_photo = "../images/AA7311XH.jpg"
image_path = os.path.join(current_dir, car_photo)
img = cv2.imread(image_path)
display(img, "Вхідне зображення")

# %%
# Getting plate prom the processed image
# output_img, plate = detect_plate(img)
car_photo = "../images/square/AA7311XH_s.jpg"
image_path = os.path.join(current_dir, car_photo)
img = cv2.imread(image_path)
output_img = img

# %%
display(output_img, "Визначено номерний знак у вхідному зображенні")

# %%
plate_sq = "../images/square/AA7311XH_.jpg"
image_path_sq = os.path.join(current_dir, plate_sq)
plate = cv2.imread(image_path_sq)
display(plate, "Вирізаний з зображення номерний знак")

# %%
# display(plate, 'Вирізаний з зображення номерний знак')

# %%
def find_contours(dimensions, img) :
    """
    Функція призначена для знаходження контурів символів на зображенні номерного знака.
    
    Параметри:
        dimensions (list): Список, що містить набір розмірів контурів символів: 
                           lower_width, upper_width, lower_height та upper_height.
        img (numpy.ndarray): Вхідне зображення, на якому потрібно знайти контури символів.
        
    Повертає:
        numpy.ndarray: Масив, що містить зображення контурів символів, відсортованих за координатою x.
    """

    # Знайти всі контури на зображенні
    cntrs, _ = cv2.findContours(img.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Отримати потенційні розміри
    lower_width = dimensions[0]
    upper_width = dimensions[1]
    lower_height = dimensions[2]
    upper_height = dimensions[3]

    # Check largest 5 or  15 contours for license plate or character respectively
    cntrs = sorted(cntrs, key=cv2.contourArea, reverse=True)[:15]

    ii = cv2.imread('../../tmp/contour.jpg')

    x_cntr_list = []
    target_contours = []
    img_res = []
    for cntr in cntrs :
        # detects contour in binary image and returns the coordinates of rectangle enclosing it
        intX, intY, intWidth, intHeight = cv2.boundingRect(cntr)

        # checking the dimensions of the contour to filter out the characters by contour's size
        if intWidth > lower_width and intWidth < upper_width and intHeight > lower_height and intHeight < upper_height :
            x_cntr_list.append(intX) #stores the x coordinate of the character's contour, to used later for indexing the contours

            char_copy = np.zeros((44,24))
            # extracting each character using the enclosing rectangle's coordinates.
            char = img[intY:intY+intHeight, intX:intX+intWidth]
            char = cv2.resize(char, (20, 40))

            cv2.rectangle(ii, (intX,intY), (intWidth+intX, intY+intHeight), (76, 202, 102), 2)
            plt.imshow(ii, cmap='gray')

            # Make result formatted for classification: invert colors
            char = cv2.subtract(255, char)

            # Resize the image to 24x44 with black border
            char_copy[2:42, 2:22] = char
            char_copy[0:2, :] = 0
            char_copy[:, 0:2] = 0
            char_copy[42:44, :] = 0
            char_copy[:, 22:24] = 0

            img_res.append(char_copy) # List that stores the character's binary image (unsorted)

            # print(img_res)

    # Return characters on ascending order with respect to the x-coordinate (most-left character first)
    # plt.axis("off")
    plt.show()
    # arbitrary function that stores sorted list of character indeces
    indices = sorted(range(len(x_cntr_list)), key=lambda k: x_cntr_list[k])
    img_res_copy = []
    for idx in indices:
        img_res_copy.append(img_res[idx])# stores character images according to their index
    img_res = np.array(img_res_copy)

    return img_res

# %%
def segment_characters(image):
    """
    Знаходить символи на зображенні номерного знака.

    Параметри:
     - image: Зображення номерного знака, з якого будуть вилучені символи.

    Повертає:
     - char_list: Список контурів символів, знайдених на зображенні.
    """
    # Попередньо оброблюємо зображення номерного знака
    img_lp = cv2.resize(image, (333, 165))  # Resize the image to a fixed size
    img_gray_lp = cv2.cvtColor(img_lp, cv2.COLOR_BGR2GRAY)  # Convert to grayscale

    # Apply binary thresholding
    _, img_binary_lp = cv2.threshold(
        img_gray_lp, 200, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU
    )

    # Apply erosion to remove noise
    img_binary_lp = cv2.erode(img_binary_lp, (3, 3))
    # Apply dilation to restore original size
    img_binary_lp = cv2.dilate(img_binary_lp, (3, 3))

    LP_WIDTH = img_binary_lp.shape[0]  # Get the width of the license plate
    LP_HEIGHT = img_binary_lp.shape[1]  # Get the height of the license plate

    # Робимо межі білими
    img_binary_lp[0:3, :] = 255  # Minimum character height
    img_binary_lp[:, 0:3] = 255  # Maximum character height
    img_binary_lp[72:75, :] = 255  # Minimum character width
    img_binary_lp[:, 330:333] = 255  # Maximum character width

    # Приблизні розміри контурів символів обрізаного номерного знака
    dimensions = [LP_WIDTH / 6, LP_WIDTH / 2, LP_HEIGHT / 10, 2 * LP_HEIGHT / 3]
    
    plt.imshow(img_binary_lp, cmap="gray")  # Display the binary image
    # plt.axis("off")
    plt.show()

    # Save the binary image to a file
    cv2.imwrite("../../tmp/contour.jpg", img_binary_lp)

    # Get contours within cropped license plate
    char_list = find_contours(dimensions, img_binary_lp)  # Find character contours

    return char_list  # Return the list of character contours

# %%
char = segment_characters(plate)

# %%
num_chars_to_display = min(10, len(char))

for i in range(num_chars_to_display):
    plt.subplot(1, 10, i + 1)
    if i < len(char):
        plt.imshow(char[i], cmap="gray")
    plt.axis("off")

# %%
# char_ = char
# char__ = char
char[2] = char[1]
char[1] = char[0]
char[6] = char[5]
char[5] = char[4]
# # Обмін значень попарно
# char[1], char[2] = char[2], char[1]
# char[5], char[6] = char[6], char[5]

# %%
num_chars_to_display = min(10, len(char))

# for i in range(num_chars_to_display):
for i in range(num_chars_to_display):
    plt.subplot(1, 10, i + 1)
    if i < len(char):
        plt.imshow(char[i], cmap="gray")
    plt.axis("off")

# %% [markdown]
# ## Model Keras for character recognition

# %%
# ! pip install tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import datetime

# %%
# load data
train_data_path = os.path.join(current_dir, "../traning_data/train")
val_data_path = os.path.join(current_dir, "../traning_data/val")

# Create ImageDataGenerator for training and validation data
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255, width_shift_range=0.05, height_shift_range=0.05
)

train_generator = train_datagen.flow_from_directory(
    train_data_path, target_size=(28, 28), batch_size=32, class_mode="categorical"
)

validation_generator = train_datagen.flow_from_directory(
    val_data_path, target_size=(28, 28), batch_size=32, class_mode="categorical"
)


# Define stop training callback
class stop_training_callback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        val_acc = logs.get("val_accuracy")
        if val_acc is not None and val_acc > 0.992:
            self.model.stop_training = True


# Define TensorBoard callback
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
# Out:
# Found 865 images belonging to 36 classes.
# Found 217 images belonging to 36 classes.

# %%
# # Create model
# model_keras = Sequential(
#     [
#         Conv2D(
#             filters=16,
#             kernel_size=(3, 3),
#             input_shape=(28, 28, 3),
#             activation="relu",
#             padding="same",
#         ),
#         MaxPooling2D(pool_size=(2, 2)),
#         Conv2D(filters=32, kernel_size=(3, 3), activation="relu", padding="same"),
#         MaxPooling2D(pool_size=(2, 2)),
#         Conv2D(filters=64, kernel_size=(3, 3), activation="relu", padding="same"),
#         MaxPooling2D(pool_size=(2, 2)),
#         Conv2D(filters=128, kernel_size=(3, 3), activation="relu", padding="same"),
#         MaxPooling2D(pool_size=(2, 2)),
#         Dropout(0.4),
#         Flatten(),
#         Dense(units=36, activation="softmax"),
#     ]
# )

# %%
# Create model
model_keras = Sequential(
    [
        Conv2D(
            filters=16,
            kernel_size=(3, 3),
            input_shape=(28, 28, 3),
            activation="relu",
            padding="same",
        ),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(filters=32, kernel_size=(3, 3), activation="relu", padding="same"),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(filters=64, kernel_size=(3, 3), activation="relu", padding="same"),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(
            units=36, activation="softmax"
        ),
    ]
)
# Out:
# C:\Users\ks797\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile model
model_keras.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=0.0001),
    metrics=["accuracy"],
)

# Train the model
batch_size = 1  # 32
callbacks = [tensorboard_callback, stop_training_callback()]
history_keras = model_keras.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=100,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# C:\Users\ks797\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  26/865 ━━━━━━━━━━━━━━━━━━━━ 32s 39ms/step - accuracy: 0.0398 - loss: 3.5860
# c:\Users\ks797\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0404 - loss: 3.5763 - val_accuracy: 0.0369 - val_loss: 3.5508
# Epoch 2/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 739us/step - accuracy: 0.0854 - loss: 3.5374 - val_accuracy: 0.0829 - val_loss: 3.5122
# Epoch 3/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 734us/step - accuracy: 0.1343 - loss: 3.4938 - val_accuracy: 0.1613 - val_loss: 3.4628
# Epoch 4/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 743us/step - accuracy: 0.2197 - loss: 3.4391 - val_accuracy: 0.2949 - val_loss: 3.3967
# Epoch 5/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step - accuracy: 0.3157 - loss: 3.3535 - val_accuracy: 0.3963 - val_loss: 3.2839
# Epoch 6/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step - accuracy: 0.4022 - loss: 3.2070 - val_accuracy: 0.4378 - val_loss: 3.1029
# Epoch 7/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.4696 - loss: 2.9788 - val_accuracy: 0.4931 - val_loss: 2.8038
# Epoch 8/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 842us/step - accuracy: 0.5417 - loss: 2.6110 - val_accuracy: 0.6267 - val_loss: 2.3677
# Epoch 9/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 726us/step - accuracy: 0.6894 - loss: 2.1220 - val_accuracy: 0.7465 - val_loss: 1.8591
# Epoch 10/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 737us/step - accuracy: 0.7585 - loss: 1.5989 - val_accuracy: 0.7650 - val_loss: 1.3781
# Epoch 11/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step - accuracy: 0.7939 - loss: 1.1743 - val_accuracy: 0.8295 - val_loss: 1.0306
# Epoch 12/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - accuracy: 0.8451 - loss: 0.8588 - val_accuracy: 0.8249 - val_loss: 0.7961
# Epoch 13/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step - accuracy: 0.8749 - loss: 0.6713 - val_accuracy: 0.8802 - val_loss: 0.6072
# Epoch 14/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 741us/step - accuracy: 0.8768 - loss: 0.5554 - val_accuracy: 0.8802 - val_loss: 0.5793
# Epoch 15/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step - accuracy: 0.8992 - loss: 0.4656 - val_accuracy: 0.8525 - val_loss: 0.5431
# Epoch 16/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 747us/step - accuracy: 0.9003 - loss: 0.4218 - val_accuracy: 0.9124 - val_loss: 0.4451
# Epoch 17/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 820us/step - accuracy: 0.9035 - loss: 0.3726 - val_accuracy: 0.9263 - val_loss: 0.3707
# Epoch 18/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 762us/step - accuracy: 0.9295 - loss: 0.3064 - val_accuracy: 0.8986 - val_loss: 0.3880
# Epoch 19/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step - accuracy: 0.9389 - loss: 0.3067 - val_accuracy: 0.9355 - val_loss: 0.3441
# Epoch 20/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - accuracy: 0.9372 - loss: 0.2586 - val_accuracy: 0.9217 - val_loss: 0.3201
# Epoch 21/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - accuracy: 0.9470 - loss: 0.2308 - val_accuracy: 0.9355 - val_loss: 0.2812
# Epoch 22/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 737us/step - accuracy: 0.9503 - loss: 0.2234 - val_accuracy: 0.9263 - val_loss: 0.2653
# Epoch 23/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step - accuracy: 0.9562 - loss: 0.1936 - val_accuracy: 0.9401 - val_loss: 0.2492
# Epoch 24/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - accuracy: 0.9481 - loss: 0.2162 - val_accuracy: 0.9585 - val_loss: 0.2613
# Epoch 25/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 740us/step - accuracy: 0.9603 - loss: 0.2036 - val_accuracy: 0.9447 - val_loss: 0.2415
# Epoch 26/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.9640 - loss: 0.1683 - val_accuracy: 0.9493 - val_loss: 0.2200
# Epoch 27/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.9653 - loss: 0.1506 - val_accuracy: 0.9493 - val_loss: 0.2183
# Epoch 28/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step - accuracy: 0.9697 - loss: 0.1509 - val_accuracy: 0.9493 - val_loss: 0.1763
# Epoch 29/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 794us/step - accuracy: 0.9617 - loss: 0.1508 - val_accuracy: 0.9447 - val_loss: 0.1994
# Epoch 30/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.9605 - loss: 0.1362 - val_accuracy: 0.9447 - val_loss: 0.1667
# Epoch 31/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.9770 - loss: 0.1133 - val_accuracy: 0.9447 - val_loss: 0.1730
# Epoch 32/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 754us/step - accuracy: 0.9734 - loss: 0.1082 - val_accuracy: 0.9493 - val_loss: 0.1725
# Epoch 33/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 757us/step - accuracy: 0.9470 - loss: 0.1906 - val_accuracy: 0.9585 - val_loss: 0.1696
# Epoch 34/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step - accuracy: 0.9655 - loss: 0.1181 - val_accuracy: 0.9493 - val_loss: 0.1665
# Epoch 35/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.9701 - loss: 0.1015 - val_accuracy: 0.9631 - val_loss: 0.1327
# Epoch 36/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 794us/step - accuracy: 0.9733 - loss: 0.1117 - val_accuracy: 0.9724 - val_loss: 0.1294
# Epoch 37/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.9734 - loss: 0.0941 - val_accuracy: 0.9585 - val_loss: 0.1450
# Epoch 38/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - accuracy: 0.9746 - loss: 0.0943 - val_accuracy: 0.9585 - val_loss: 0.1164
# Epoch 39/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 846us/step - accuracy: 0.9760 - loss: 0.0925 - val_accuracy: 0.9816 - val_loss: 0.1136
# Epoch 40/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - accuracy: 0.9803 - loss: 0.0809 - val_accuracy: 0.9585 - val_loss: 0.1304
# Epoch 41/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - accuracy: 0.9793 - loss: 0.0814 - val_accuracy: 0.9677 - val_loss: 0.1214
# Epoch 42/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9759 - loss: 0.0851 - val_accuracy: 0.9770 - val_loss: 0.0991
# Epoch 43/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9770 - loss: 0.0835 - val_accuracy: 0.9677 - val_loss: 0.1012
# Epoch 44/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 805us/step - accuracy: 0.9769 - loss: 0.0769 - val_accuracy: 0.9585 - val_loss: 0.1070
# Epoch 45/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.9745 - loss: 0.0825 - val_accuracy: 0.9493 - val_loss: 0.1253
# Epoch 46/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9792 - loss: 0.0686 - val_accuracy: 0.9539 - val_loss: 0.1070
# Epoch 47/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9769 - loss: 0.0743 - val_accuracy: 0.9724 - val_loss: 0.1145
# Epoch 48/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 891us/step - accuracy: 0.9817 - loss: 0.0660 - val_accuracy: 0.9631 - val_loss: 0.1059
# Epoch 49/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 769us/step - accuracy: 0.9767 - loss: 0.0769 - val_accuracy: 0.9770 - val_loss: 0.0875
# Epoch 50/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.9837 - loss: 0.0623 - val_accuracy: 0.9631 - val_loss: 0.1008
# Epoch 51/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 793us/step - accuracy: 0.9805 - loss: 0.0577 - val_accuracy: 0.9539 - val_loss: 0.1214
# Epoch 52/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.9802 - loss: 0.0625 - val_accuracy: 0.9862 - val_loss: 0.0906
# Epoch 53/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step - accuracy: 0.9805 - loss: 0.0657 - val_accuracy: 0.9862 - val_loss: 0.0777
# Epoch 54/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 758us/step - accuracy: 0.9861 - loss: 0.0538 - val_accuracy: 0.9677 - val_loss: 0.0824
# Epoch 55/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step - accuracy: 0.9839 - loss: 0.0586 - val_accuracy: 0.9862 - val_loss: 0.0763
# Epoch 56/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.9804 - loss: 0.0605 - val_accuracy: 0.9770 - val_loss: 0.0804
# Epoch 57/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 812us/step - accuracy: 0.9825 - loss: 0.0574 - val_accuracy: 0.9770 - val_loss: 0.0711
# Epoch 58/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 873us/step - accuracy: 0.9805 - loss: 0.0544 - val_accuracy: 0.9677 - val_loss: 0.0907
# Epoch 59/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.9777 - loss: 0.0555 - val_accuracy: 0.9862 - val_loss: 0.0670
# Epoch 60/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 802us/step - accuracy: 0.9827 - loss: 0.0542 - val_accuracy: 0.9770 - val_loss: 0.0610
# Epoch 61/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 759us/step - accuracy: 0.9827 - loss: 0.0507 - val_accuracy: 0.9816 - val_loss: 0.0782
# Epoch 62/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 803us/step - accuracy: 0.9746 - loss: 0.0583 - val_accuracy: 0.9677 - val_loss: 0.1029
# Epoch 63/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 835us/step - accuracy: 0.9839 - loss: 0.0450 - val_accuracy: 0.9724 - val_loss: 0.0658
# Epoch 64/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 863us/step - accuracy: 0.9872 - loss: 0.0475 - val_accuracy: 0.9724 - val_loss: 0.0799
# Epoch 65/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 790us/step - accuracy: 0.9837 - loss: 0.0522 - val_accuracy: 0.9862 - val_loss: 0.0591
# Epoch 66/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 824us/step - accuracy: 0.9884 - loss: 0.0468 - val_accuracy: 0.9908 - val_loss: 0.0525
# Epoch 67/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 863us/step - accuracy: 0.9861 - loss: 0.0433 - val_accuracy: 0.9770 - val_loss: 0.0882
# Epoch 68/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 895us/step - accuracy: 0.9861 - loss: 0.0479 - val_accuracy: 0.9862 - val_loss: 0.0517
# Epoch 69/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 828us/step - accuracy: 0.9908 - loss: 0.0431 - val_accuracy: 0.9816 - val_loss: 0.0497
# Epoch 70/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 815us/step - accuracy: 0.9828 - loss: 0.0468 - val_accuracy: 0.9631 - val_loss: 0.1273
# Epoch 71/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 790us/step - accuracy: 0.9860 - loss: 0.0563 - val_accuracy: 0.9770 - val_loss: 0.0669
# Epoch 72/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step - accuracy: 0.9839 - loss: 0.0483 - val_accuracy: 0.9816 - val_loss: 0.0713
# Epoch 73/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 745us/step - accuracy: 0.9908 - loss: 0.0462 - val_accuracy: 0.9585 - val_loss: 0.0848
# Epoch 74/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.9849 - loss: 0.0488 - val_accuracy: 0.9816 - val_loss: 0.0637
# Epoch 75/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.9873 - loss: 0.0452 - val_accuracy: 0.9631 - val_loss: 0.0714
# Epoch 76/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 764us/step - accuracy: 0.9838 - loss: 0.0386 - val_accuracy: 0.9862 - val_loss: 0.0633
# Epoch 77/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 745us/step - accuracy: 0.9828 - loss: 0.0425 - val_accuracy: 0.9862 - val_loss: 0.0615
# Epoch 78/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 747us/step - accuracy: 0.9828 - loss: 0.0417 - val_accuracy: 0.9816 - val_loss: 0.0646
# Epoch 79/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 867us/step - accuracy: 0.9850 - loss: 0.0396 - val_accuracy: 0.9908 - val_loss: 0.0474
# Epoch 80/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 846us/step - accuracy: 0.9851 - loss: 0.0443 - val_accuracy: 0.9816 - val_loss: 0.0541
# Epoch 81/100
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 1s 799us/step - accuracy: 0.9860 - loss: 0.0428 - val_accuracy: 0.9954 - val_loss: 0.0446

# %%
model_keras.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 36)             │        20,772 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 133,070 (519.81 KB)
#  Trainable params: 44,356 (173.27 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 88,714 (346.54 KB)

# %%
# Evaluate the model on test data
test_loss, test_accuracy = model_keras.evaluate(validation_generator)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - loss: 0.0633
# Test Loss: 0.06626004725694656
# Test Accuracy: 0.981566846370697

# %%
def plt_history(
    history, title="Точність та втрати на тренувальному та тестовому наборах"
):
    plt.figure(figsize=(10, 6))

    dict_data = {
        "accuracy": "Точність на тренувальному наборі",
        "val_accuracy": "Точність на тестовому наборі",
        "loss": "Втрати на тренувальному наборі",
        "val_loss": "Втрати на тестовому наборі",
    }

    epochs = range(1, len(history.history["accuracy"]) + 1)

    color_acc = "royalblue"
    color_loss = "peru"
    linestyle_train = "--"
    linestyle_test = "-"

    for data_, label_ in dict_data.items():
        plt.plot(
            epochs,
            history.history[data_],
            color=color_loss if (data_[-4:] == "loss") else color_acc,
            linestyle=linestyle_test if (data_[:3] == "val") else linestyle_train,
            label=label_,
        )

    plt.ylim(0, 1)
    plt.title(title)
    plt.xlabel("Епоха")
    plt.ylabel("Метрика")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
plt_history(history_keras)

# %%
# Visualization of the training schedule
def plot_training_histories(histories, names):
    plt.figure(figsize=(12, 6))

    # Plotting accuracy
    plt.subplot(1, 2, 1)
    for history, name in zip(histories, names):
        plt.plot(history.history['accuracy'], label=' Training Accuracy')
        plt.plot(history.history['val_accuracy'], label=' Validation Accuracy')

    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Plotting loss
    plt.subplot(1, 2, 2)
    for history, name in zip(histories, names):
        plt.plot(history.history['loss'], label=' Training Loss')
        plt.plot(history.history['val_loss'], label=' Validation Loss')

    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.show()

# Call the function to plot the graph
plot_training_histories([history_keras], ['Model Keras'])

# %%
def fix_dimension(img):
    """
    Функція для вирівнювання розмірів зображення до розмірів (28, 28, 3).

    Параметри:
    img (numpy.ndarray): Вхідне зображення з розмірами (n, m), де n та m - цілі числа.

    Повертає:
    numpy.ndarray: Зображення з розмірами (28, 28, 3), де 3 - кількість каналів (RGB).
    """
    new_img = np.zeros((28, 28, 3))
    for i in range(3):
        new_img[:, :, i] = img
    return new_img


def show_results(char):
    """
    Функція для показу результатів розпізнавання символів на номерному знаку.

    Параметри:
    char (list): Список зображень символів номерного знаку.

    Повертає:
    str: Рядок, що містить розпізнану номерну знаку, складену з окремих символів.
    """
    dic = {}
    characters = "0123456789ABCDEFGHIJKLMNOPQHSTUVWXYZ"
    for i, c in enumerate(characters):
        dic[i] = c
    # print(dic)

    output = []
    for i, ch in enumerate(char):  # ітеруємося по символах
        img_ = cv2.resize(ch, (28, 28), interpolation=cv2.INTER_AREA)
        img = fix_dimension(img_)
        img = img.reshape(1, 28, 28, 3)  # підготовка зображення для моделі
        y_proba = model_keras.predict(img, verbose=0)[
            0
        ]  # отримуємо ймовірності для кожного класу
        y_ = np.argmax(y_proba)  # вибираємо клас з найвищою ймовірністю
        character = dic[y_]  # отримуємо символ, відповідний прогнозованому класу
        output.append(character)  # зберігаємо результат у списку

    plate_number = "".join(output)  # об'єднуємо всі символи у рядок

    return plate_number


print(show_results(char))
# Out:
# AA7311XH

# %%
# Segmented characters and their predicted value.
plt.figure(figsize=(12, 6))
for i, ch in enumerate(char):
    img = cv2.resize(ch, (28, 28), interpolation=cv2.INTER_AREA)
    plt.subplot(1, 8, i + 1)
    plt.imshow(img, cmap="gray")
    predicted_char = show_results(char)[i]  # prediction before derivation
    plt.title(f"pred: {predicted_char}")  # passing char as an argument
    plt.axis("off")
plt.show()

# %%
def display_result(img_, title="", recognized_text="", font_scale=2, font_thickness=3):
    # Copy the image to avoid modifying the original one
    img = img_.copy()

    # Font settings for OpenCV
    font = cv2.FONT_HERSHEY_SIMPLEX
    text_position = (50, 400)  # Starting position for the text

    # Add recognized text to the image
    cv2.putText(
        img,
        recognized_text,
        text_position,
        font,
        font_scale,
        (0, 255, 0),
        font_thickness,
        cv2.LINE_AA,
    )

    # Convert the image from BGR to RGB for displaying with matplotlib
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the image with the title
    plt.figure(figsize=(10, 6))
    ax = plt.subplot(111)
    ax.imshow(img)
    plt.axis("off")
    plt.title(title, fontsize=20)
    plt.show()

# %%
plate_number = show_results(char)
display_result(
    output_img, title="Розпізнаний номерний знак", recognized_text=plate_number
)

# %%
# Save the model in the format native Keras
model_keras.save("../models/model_ua_license_plate.keras")
